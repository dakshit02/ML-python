# %%
#for loop 
range(5)
# Out:
# range(0, 5)

# %%
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10,1,-1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
# while loop 
count = 0 
while (count <5):
    print(count)
    count+=1
# Out:
# 0
# 1
# 2
# 3
# 4
