# %%
print("dakshit ")
# Out:
# dakshit

# %%
print("hi ")
# Out:
# hi

# %%
#declaring and assigniging the variables
age = 32 
height =6.1
name= "dakshit "
is_student = True

#printing the var
print("age:",age)
print("age:",height)
print("age:",is_student)
# Out:
# age: 32
# age: 6.1
# age: True

# %%
# type checking and Conversion 
height = 25
type(height)
print(type(age))
# Out:
# <class 'int'>
