# %%
print("hi my name is dakshit chandel")
# Out:
# hi my name is dakshit chandel

# %%
name = "dakshit"
Name="chandel"

print(name)
print(Name)
# Out:
# dakshit
# chandel

# %% [markdown]
# ### Indentation

# %%
age =23
if age <40:
    print(age)

print("hi")
# Out:
# 23
# hi

# %%
## multiple statement
x =5 ;y=10;z=x+y
print(z)
# Out:
# 15

# %%
#semantics 
#variable assignment 
age = 32 
name = "Dakshit Chandel"

print(age)
print(name)
# Out:
# 32
# Dakshit Chandel

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
#type inference
variable =10
print(type(variable))
variable ="dakshit"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>
