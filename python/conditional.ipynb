# %%
age =16 

if(age>=18):
    print("You are eligible to vote")
else:
    print("you are a minor ")
# Out:
# you are a minor

# %%
age =20 
if (age<13):
    print("wow")
elif(age>15):
    print("ok")
else:
    print("nahi to ye he karna padega")
# Out:
# ok
