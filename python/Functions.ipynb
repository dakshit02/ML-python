# %% [markdown]
# Functions

# %%
def new_function(x):
    print(x)
    return 0


new_function(23)
# Out:
# 23
# 0

# %%
NUM = 24

# %%
def odd_even(NUM):
    if NUM % 2 == 0:
        print(f"{NUM} is even")
    else:
        print("odd")
        

#calling the function
odd_even(NUM)
# Out:
# 24 is even
