# %%
#Assignment 7
nested_list = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]

# print(nested_list)
for row in nested_list:
    print(row)
print(nested_list[1][2])
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]
# 6

# %%
list_of_dictionary=[
    { "name":"dakshit","score":90 },
    {"name":"shubham","score":88},
    {"name":"agan","score":80}
]
    
for rows in list_of_dictionary:
    print(rows)
# Out:
# {'name': 'dakshit', 'score': 90}
# {'name': 'shubham', 'score': 88}
# {'name': 'agan', 'score': 80}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 10
#       7 for rows in list_of_dictionary:
#       8     print(rows)
# ---> 10 print(list_of_dictionary[1][1])
#
# KeyError: 1
