# %%
#Assignment 7
nested_list = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]

# print(nested_list)
for row in nested_list:
    print(row)
print(nested_list[1][2])
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]
# 6

# %%
list_of_dictionary=[
    { "name":"dakshit","score":30 },
    {"name":"shubham","score":88},
    {"name":"agan","score":80}
]
    
# for rows in list_of_dictionary:
#     print(rows)

#sorting the list of dictonaries by the score 
# sorted() → returns a NEW list
# .sort() → changes the original list


sorted_list = sorted(list_of_dictionary,key=lambda x : x['score'],reverse = True)
for i in sorted_list:
    print(i)
# Out:
# {'name': 'shubham', 'score': 88}
# {'name': 'agan', 'score': 80}
# {'name': 'dakshit', 'score': 30}

# %%
#Assignment 9
#Transpose Matrix
a1=int(input("Enter a number:"))
a2=int(input("Enter a number:"))
a3=int(input("Enter a number:"))
b1=int(input("Enter a number:"))
b2=int(input("Enter a number:"))
b3=int(input("Enter a number:"))
c1=int(input("Enter a number:"))
c2=int(input("Enter a number:"))
c3=int(input("Enter a number:"))
matrix = [
    [a1,a2,a3],
    [b1,b2,b3],
    [c1,c2,c3]

]

trans_matirx = [
    [a1,b1,c1],
    [a2,b2,c2],
    [a3,b3,c3]

]

for row in matrix :
    print(row)

print("Transpose matrix for the above is : - ")

for row in trans_matirx:
    print(row)
# Out:
# [12, 13, 14]
# [15, 16, 17]
# [18, 19, 20]
# Transpose matrix for the above is : -
# [12, 15, 18]
# [13, 16, 19]
# [14, 17, 20]
