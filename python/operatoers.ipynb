# %%
print("hi")
# Out:
# hi

# %%
#arthemetics operations
a=10
b =5

add_result = a+b
sub_result = a-b
mult_result = a*b
div_result = a/b
floor_div_result=a//b    #the ans will be in int 
modulus_result = a%b
exponent_result = a**b

print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
print(floor_div_result)
print(modulus_result)
print(exponent_result)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %% [markdown]
# Logical Operators

# %%
#AND
X = True
Y = False

result = X and Y

print(result)
# Out:
# False

# %%
#or
X = True
Y = False

result = X or Y

print(result)
# Out:
# True

# %%
#not
X = True
not X
# Y = False

# result = X and Y

# print(not result)
# Out:
# False
